# %%
#import standard libraries for data pre-processing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Load data set using the pandas read function
data=pd.read_csv(r"C:\Users\USER\Videos\Data Analyst Bootcamp\projects\Healthcare\healthcare_dataset.csv")

# %%
data.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        2022-11-17  Patrick Parker           Wallace-Hamilton
# 1        2023-06-01   Diane Jackson  Burke, Griffin and Cooper
# 2        2019-01-09      Paul Baker                 Walton LLC
# 3        2020-05-02  Brian Chandler                 Garcia Ltd
# 4        2021-07-09  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare    37490.983364          146       Elective
# 1   UnitedHealthcare    47304.064845          404      Emergency
# 2           Medicare    36874.896997          292      Emergency
# 3           Medicare    23303.322092          480         Urgent
# 4   UnitedHealthcare    18086.344184          477         Urgent
#
#   Discharge Date   Medication  Test Results
# 0     2022-12-01      Aspirin  Inconclusive
# 1     2023-06-15      Lipitor        Normal
# 2     2019-02-08      Lipitor        Normal
# 3     2020-05-03   Penicillin      Abnormal
# 4     2021-08-02  Paracetamol        Normal

# %%
#Checking the data shape
data.shape
# Out:
# (10000, 15)

# %%
#CHecking the information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 1.1+ MB

# %%
# Null value checking
data.isna().sum()/len(data)*100
# Out:
# Name                  0.0
# Age                   0.0
# Gender                0.0
# Blood Type            0.0
# Medical Condition     0.0
# Date of Admission     0.0
# Doctor                0.0
# Hospital              0.0
# Insurance Provider    0.0
# Billing Amount        0.0
# Room Number           0.0
# Admission Type        0.0
# Discharge Date        0.0
# Medication            0.0
# Test Results          0.0
# dtype: float64

# %%
#Duplicate values check
Checking_duplicate_values=data.duplicated().sum()
print(f'The data set contains the {Checking_duplicate_values} values')
# Out:
# The data set contains the 0 values

# %%
#Observations:
    #e data contains 10000 rows and 15 columns
    #?*there is no null and duplicate values in the data
    #In the age column ,minimum age is 18 and maximum goes to 85
    
    #xplore Data Analysis Process
    #Questions asked from the data
    #Create  a pie chart to represent the percentage distribution of each blood group
    #Generate a bar graph to highlight the top 10 regular customers based on relevant dataset
    #Utilize e a bar graph to identify and visualize the busiest doctor within the dataset
    #Create pie chart to illustrate the percentage distribution of genders in the dataset
    #Generalize a visualization, possibly a histogram or another suitable chat to represent the distribution of age values in the dataset
    

         #Checking the blood percentage inthe dataset
     data['Blood Type'].value_counts().sort_values(ascending=False)\
.plot(kind='pie',
     title="Visualize the Blood type percentage in the data",
      explode=[0,0,0,0,0,0,0,0.001],
      labels=['AB-','AB+','B-','O+','O-','B+','A+','A-'], 
      colors=['#f72585','#778da9','#9b2226','#000814','#83c5be','#a3a380'], 
      autopct='%1.2f%%',
      pctdistance=0.6, 
      shadow=True)
plt.show()
# Out:
#   File "<ipython-input-30-98e14070f8f0>", line 16
#     data['Blood Type'].value_counts().sort_values(ascending=False)\
#     ^
# IndentationError: unexpected indent

# %%
 data['Blood Type'].value_counts().sort_values(ascending=False)\
.plot(kind='pie',
     title="Visualize the Blood type percentage in the data",
      explode=[0,0,0,0,0,0,0,0.001],
      labels=['AB-','AB+','B-','O+','O-','B+','A+','A-'], 
      colors=['#f72585','#778da9','#9b2226','#000814','#83c5be','#a3a380'], 
      autopct='%1.2f%%',
      pctdistance=0.6, 
      shadow=True)
plt.show()

# %%
# Checking the regular customers
data['Name'].value_counts().sort_values(ascending=False).head(10)\
.plot(kind='bar',figsize=(10,5),title="Regular patients in the hostpital",color=['#588157','#f77f00','#003049','#a8dadc','#9e2a2b'])
plt.xlabel("Patients names")
plt.ylabel("How many times they visit the hospital")
plt.show()

# %%
# Checking the same age people
colors_values=['#c1121f','#ff99c8','#540b0e','#9b2226','#415a77','#f72585']
data['Age'].value_counts().sort_values(ascending=False).head(20)\
.plot(kind='bar',figsize=(10,5),color=colors_values,title="Checking the same ages perosons in the data")
plt.xlabel("Age")
plt.ylabel("How many meMbers in the same age in the data")
plt.show()

# %%
# Find the Gender percentage in the data set
data['Gender'].value_counts().sort_values(ascending=False)\
.plot(kind='pie',title="Visualize the Gender percentage in the data",
      explode=[0,0.01],
      labels=['Female','Male'], 
      colors=['#ff7d00','#1b263b'], 
      autopct='%1.2f%%',
      shadow=True)
plt.show()

# %%
#Observations:
#AB- is the leading blood group in the dataset, followed by AB+.

#Michel Janson and James Janson are the top patients, each having visited the hospital 6 times.

#People aged 59 and 79 tend to be the most frequent visitors to the hospital.

#The female gender dominates in the dataset.

# %%
#Again questions asked from the data.

#Generate a chart to illustrate the medications used for various medical conditions in the dataset.
#Determine and visualize the day on which most patients are admitted using appropriate charts or graphs.
#Identify and display the top 10 hospitals with the highest charges paid by patients.
#Determine the doctor who earns the most and visualize this information.
#Explore and analyze the relationship between medical conditions and admission types, presenting the findings visually.

# %%
# Which medication used different medical conditions 
data.groupby('Medical Condition')['Medication'].value_counts().sort_values(ascending=False)\
.unstack().style.background_gradient(cmap='GnBu_r')
# Out:
# <style  type="text/css" >
# #T_12a14_row0_col0,#T_12a14_row5_col0{
#             background-color:  #54b6d1;
#             color:  #000000;
#         }#T_12a14_row0_col1{
#             background-color:  #4db2d3;
#             color:  #000000;
#         }#T_12a14_row0_col2,#T_12a14_row1_col3,#T_12a14_row2_col0,#T_12a14_row3_col1,#T_12a14_row5_col4{
#             background-color:  #084081;
#             color:  #f1f1f1;
#         }#T_12a14_row0_col3{
#             background-color:  #53b6d1;
#             color:  #000000;
#         }#T_12a14_row0_col4,#T_12a14_row1_col0,#T_12a14_row2_col1,#T_12a14_row2_col3,#T_12a14_row4_col2{
#             background-color:  #f7fcf0;
#             color:  #000000;
#         }#T_12a14_row1_col1{
#             background-color:  #ceecc8;
#             color:  #000000;
#         }#T_12a14_row1_col2{
#             background-color:  #c8eac3;
#             color:  #000000;
#         }#T_12a14_row1_col4{
#             background-color:  #51b5d2;
#             color:  #000000;
#         }#T_12a14_row2_col2{
#             background-color:  #dbf1d5;
#             color:  #000000;
#         }#T_12a14_row2_col4{
#             background-color:  #eef8e7;
#             color:  #000000;
#         }#T_12a14_row3_col0{
#             background-color:  #8fd4bd;
#             color:  #000000;
#         }#T_12a14_row3_col2{
#             background-color:  #1f80b8;
#             color:  #000000;
#         }#T_12a14_row3_col3{
#             background-color:  #70c6c8;
#             color:  #000000;
#         }#T_12a14_row3_col4{
#             background-color:  #1677b3;
#             color:  #f1f1f1;
#         }#T_12a14_row4_col0{
#             background-color:  #6fc5c8;
#             color:  #000000;
#         }#T_12a14_row4_col1{
#             background-color:  #b4e2ba;
#             color:  #000000;
#         }#T_12a14_row4_col3{
#             background-color:  #4aafd1;
#             color:  #000000;
#         }#T_12a14_row4_col4{
#             background-color:  #76c9c6;
#             color:  #000000;
#         }#T_12a14_row5_col1{
#             background-color:  #86d0c0;
#             color:  #000000;
#         }#T_12a14_row5_col2{
#             background-color:  #084889;
#             color:  #f1f1f1;
#         }#T_12a14_row5_col3{
#             background-color:  #a3dbb7;
#             color:  #000000;
#         }</style><table id="T_12a14_" ><thead>    <tr>        <th class="index_name level0" >Medication</th>        <th class="col_heading level0 col0" >Aspirin</th>        <th class="col_heading level0 col1" >Ibuprofen</th>        <th class="col_heading level0 col2" >Lipitor</th>        <th class="col_heading level0 col3" >Paracetamol</th>        <th class="col_heading level0 col4" >Penicillin</th>    </tr>    <tr>        <th class="index_name level0" >Medical Condition</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12a14_level0_row0" class="row_heading level0 row0" >Arthritis</th>
#                         <td id="T_12a14_row0_col0" class="data row0 col0" >322</td>
#                         <td id="T_12a14_row0_col1" class="data row0 col1" >320</td>
#                         <td id="T_12a14_row0_col2" class="data row0 col2" >318</td>
#                         <td id="T_12a14_row0_col3" class="data row0 col3" >324</td>
#                         <td id="T_12a14_row0_col4" class="data row0 col4" >366</td>
#             </tr>
#             <tr>
#                         <th id="T_12a14_level0_row1" class="row_heading level0 row1" >Asthma</th>
#                         <td id="T_12a14_row1_col0" class="data row1 col0" >370</td>
#                         <td id="T_12a14_row1_col1" class="data row1 col1" >340</td>
#                         <td id="T_12a14_row1_col2" class="data row1 col2" >346</td>
#                         <td id="T_12a14_row1_col3" class="data row1 col3" >310</td>
#                         <td id="T_12a14_row1_col4" class="data row1 col4" >342</td>
#             </tr>
#             <tr>
#                         <th id="T_12a14_level0_row2" class="row_heading level0 row2" >Cancer</th>
#                         <td id="T_12a14_row2_col0" class="data row2 col0" >291</td>
#                         <td id="T_12a14_row2_col1" class="data row2 col1" >352</td>
#                         <td id="T_12a14_row2_col2" class="data row2 col2" >350</td>
#                         <td id="T_12a14_row2_col3" class="data row2 col3" >346</td>
#                         <td id="T_12a14_row2_col4" class="data row2 col4" >364</td>
#             </tr>
#             <tr>
#                         <th id="T_12a14_level0_row3" class="row_heading level0 row3" >Diabetes</th>
#                         <td id="T_12a14_row3_col0" class="data row3 col0" >335</td>
#                         <td id="T_12a14_row3_col1" class="data row3 col1" >301</td>
#                         <td id="T_12a14_row3_col2" class="data row3 col2" >326</td>
#                         <td id="T_12a14_row3_col3" class="data row3 col3" >327</td>
#                         <td id="T_12a14_row3_col4" class="data row3 col4" >334</td>
#             </tr>
#             <tr>
#                         <th id="T_12a14_level0_row4" class="row_heading level0 row4" >Hypertension</th>
#                         <td id="T_12a14_row4_col0" class="data row4 col0" >328</td>
#                         <td id="T_12a14_row4_col1" class="data row4 col1" >335</td>
#                         <td id="T_12a14_row4_col2" class="data row4 col2" >356</td>
#                         <td id="T_12a14_row4_col3" class="data row4 col3" >323</td>
#                         <td id="T_12a14_row4_col4" class="data row4 col4" >346</td>
#             </tr>
#             <tr>
#                         <th id="T_12a14_level0_row5" class="row_heading level0 row5" >Obesity</th>
#                         <td id="T_12a14_row5_col0" class="data row5 col0" >322</td>
#                         <td id="T_12a14_row5_col1" class="data row5 col1" >328</td>
#                         <td id="T_12a14_row5_col2" class="data row5 col2" >319</td>
#                         <td id="T_12a14_row5_col3" class="data row5 col3" >332</td>
#                         <td id="T_12a14_row5_col4" class="data row5 col4" >327</td>
#             </tr>
#     </tbody></table>

# %%
# Find the date which most of the people joined
data['Date of Admission'].value_counts().sort_values(ascending=False)\
.plot(kind='line',figsize=(10,6),title="Which day most of the people joined",color=['#ff595e'])
plt.xlabel("Data")
plt.ylabel("Count of people")
plt.show()

# %%
# Top 10 high fees colleting hosptial
data.groupby('Hospital')['Billing Amount'].sum().sort_values(ascending=False).head(10)\
.plot(kind='barh',figsize=(10,6),color=['#52b69a','#5fa8d3','#0d3b66','#adc178','#6930c3'])
plt.title("Top 10 high bills paying hospital")
plt.xlabel("Hospital name")
plt.ylabel("Sum of the amount")
plt.show()

# %%
# Find which doctor mostly earn 
data.groupby('Doctor')['Billing Amount'].sum().sort_values(ascending=False).head(10)\
.plot(kind='bar',figsize=(10,6),title="Top 10 most costly doctors",color=['#dedbd2','#ee964b','#ffe5d9','#252422','#adc178'])
plt.xlabel('Doctor names')
plt.ylabel('Billing Amount')
plt.show()

# %%
# Find the admision type with different madical condition 
data.groupby('Medical Condition')['Admission Type'].value_counts()\
.unstack().style.background_gradient(cmap='seismic_r')
# Out:
# <style  type="text/css" >
# #T_834c4_row0_col0{
#             background-color:  #000055;
#             color:  #f1f1f1;
#         }#T_834c4_row0_col1,#T_834c4_row3_col2,#T_834c4_row5_col0{
#             background-color:  #800000;
#             color:  #f1f1f1;
#         }#T_834c4_row0_col2{
#             background-color:  #fc0000;
#             color:  #f1f1f1;
#         }#T_834c4_row1_col0,#T_834c4_row2_col1,#T_834c4_row4_col1,#T_834c4_row4_col2{
#             background-color:  #00004c;
#             color:  #f1f1f1;
#         }#T_834c4_row1_col1{
#             background-color:  #c9c9ff;
#             color:  #000000;
#         }#T_834c4_row1_col2{
#             background-color:  #0000ef;
#             color:  #f1f1f1;
#         }#T_834c4_row2_col0{
#             background-color:  #0000f2;
#             color:  #f1f1f1;
#         }#T_834c4_row2_col2{
#             background-color:  #c1c1ff;
#             color:  #000000;
#         }#T_834c4_row3_col0{
#             background-color:  #ff6969;
#             color:  #000000;
#         }#T_834c4_row3_col1{
#             background-color:  #b5b5ff;
#             color:  #000000;
#         }#T_834c4_row4_col0{
#             background-color:  #ce0000;
#             color:  #f1f1f1;
#         }#T_834c4_row5_col1{
#             background-color:  #0000d0;
#             color:  #f1f1f1;
#         }#T_834c4_row5_col2{
#             background-color:  #ff1d1d;
#             color:  #f1f1f1;
#         }</style><table id="T_834c4_" ><thead>    <tr>        <th class="index_name level0" >Admission Type</th>        <th class="col_heading level0 col0" >Elective</th>        <th class="col_heading level0 col1" >Emergency</th>        <th class="col_heading level0 col2" >Urgent</th>    </tr>    <tr>        <th class="index_name level0" >Medical Condition</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_834c4_level0_row0" class="row_heading level0 row0" >Arthritis</th>
#                         <td id="T_834c4_row0_col0" class="data row0 col0" >569</td>
#                         <td id="T_834c4_row0_col1" class="data row0 col1" >529</td>
#                         <td id="T_834c4_row0_col2" class="data row0 col2" >552</td>
#             </tr>
#             <tr>
#                         <th id="T_834c4_level0_row1" class="row_heading level0 row1" >Asthma</th>
#                         <td id="T_834c4_row1_col0" class="data row1 col0" >570</td>
#                         <td id="T_834c4_row1_col1" class="data row1 col1" >556</td>
#                         <td id="T_834c4_row1_col2" class="data row1 col2" >582</td>
#             </tr>
#             <tr>
#                         <th id="T_834c4_level0_row2" class="row_heading level0 row2" >Cancer</th>
#                         <td id="T_834c4_row2_col0" class="data row2 col0" >555</td>
#                         <td id="T_834c4_row2_col1" class="data row2 col1" >578</td>
#                         <td id="T_834c4_row2_col2" class="data row2 col2" >570</td>
#             </tr>
#             <tr>
#                         <th id="T_834c4_level0_row3" class="row_heading level0 row3" >Diabetes</th>
#                         <td id="T_834c4_row3_col0" class="data row3 col0" >528</td>
#                         <td id="T_834c4_row3_col1" class="data row3 col1" >557</td>
#                         <td id="T_834c4_row3_col2" class="data row3 col2" >538</td>
#             </tr>
#             <tr>
#                         <th id="T_834c4_level0_row4" class="row_heading level0 row4" >Hypertension</th>
#                         <td id="T_834c4_row4_col0" class="data row4 col0" >515</td>
#                         <td id="T_834c4_row4_col1" class="data row4 col1" >578</td>
#                         <td id="T_834c4_row4_col2" class="data row4 col2" >595</td>
#             </tr>
#             <tr>
#                         <th id="T_834c4_level0_row5" class="row_heading level0 row5" >Obesity</th>
#                         <td id="T_834c4_row5_col0" class="data row5 col0" >505</td>
#                         <td id="T_834c4_row5_col1" class="data row5 col1" >569</td>
#                         <td id="T_834c4_row5_col2" class="data row5 col2" >554</td>
#             </tr>
#     </tbody></table>

# %%
#Observations:
#For arthritis conditions, Penicillin medication is used, while for asthma, aspirin is prescribed.

#On April 12, 2019, most patients joined hospitals.

#Smith and Sons charge high amounts for their patients.

#Michel Janson is the highest-earning doctor in the dataset.

#*Also, visualize the medical conditions with admission types.

# %%
data.head(1)
# Out:
#               Name  Age  Gender Blood Type Medical Condition  \
# 0  Tiffany Ramirez   81  Female         O-          Diabetes
#
#   Date of Admission          Doctor          Hospital Insurance Provider  \
# 0        2022-11-17  Patrick Parker  Wallace-Hamilton           Medicare
#
#    Billing Amount  Room Number Admission Type Discharge Date Medication  \
# 0    37490.983364          146       Elective     2022-12-01    Aspirin
#
#    Test Results
# 0  Inconclusive

# %%
# Let's find the average amount for the gender with billing amount
pd.DataFrame(data.groupby('Gender')['Billing Amount'].mean().sort_values(ascending=False)).style
# Out:
# <style  type="text/css" >
# </style><table id="T_3f762_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Billing Amount</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3f762_level0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_3f762_row0_col0" class="data row0 col0" >25550.215933</td>
#             </tr>
#             <tr>
#                         <th id="T_3f762_level0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_3f762_row1_col0" class="data row1 col0" >25484.385085</td>
#             </tr>
#     </tbody></table>

# %%
# Find the smit and sons hospital insuarance providers 
data.groupby('Hospital')['Insurance Provider'].value_counts().loc['Smith and Sons']\
.plot(kind='bar',title="Smith and Sons High insurance agent",figsize=(10,4),color=['#84a98c','#880d1e','#072ac8','#cbeef3','#31572c'])
plt.xlabel("Insurance Agent")
plt.ylabel("Count of values")
plt.show()

# %%
# Find the which insurace are providing insurance for diabetes
diabetes=data['Medical Condition']=='Diabetes'
data.loc[diabetes]['Insurance Provider'].value_counts()\
.plot(kind='pie',
     title="Visualize the diabetes  with insurance provider percentage in the data",
      explode=[0,0,0,0,0.01],
      labels=['Blue Cross','Medicare','Aetna','Cigna','UnitedHealthcare'], 
      colors=['#6b9080','#cce3de','#8ac926','#fc6e6e','#17c3b2'], 
      autopct='%1.2f%%',
      shadow=True)
# Out:
# <AxesSubplot:title={'center':'Visualize the diabetes  with insurance provider percentage in the data'}, ylabel='Insurance Provider'>

# %%
# To visualize the 
plt.figure(figsize=(10,5))
for i in ['Medical Condition','Insurance Provider','Blood Type','Gender']:
    sns.countplot(data=data,x=i,hue='Test Results',palette='tab10')
    plt.title(f'The information about {i} to compare the test result')
    plt.xlabel(f'The {i} information')
    plt.ylabel('Test Results')
    plt.show()

# %%
# Find the average billing amount for the each desies
data.groupby('Medical Condition')['Billing Amount'].mean().sort_values(ascending=False)\
.plot(kind='bar',title="Average billing amount for all diseases",figsize=(10,5),color=['#ffb3c6','#001d3d','#34a0a4','#826a5e'])
plt.xlabel("Medical Condition")
plt.ylabel("Average Billing amount")
plt.show()
